# %% [markdown]
# Agent Development Kit (ADK) is a flexible and modular framework for developing and deploying AI agents. While optimized for Gemini and the Google ecosystem, ADK is model-agnostic, deployment-agnostic, and is built for compatibility with other frameworks

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install google-adk
# Out:
# Requirement already satisfied: google-adk in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (1.18.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (8.3.0)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.121.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.126.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (3.5.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.49.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.21.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.12.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.49.3)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (46.0.3)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from click<9.0.0,>=8.1.8->google-adk) (0.4.5)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from fastapi<1.119.0,>=0.115.0->google-adk) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (6.33.0)
# Requirement already satisfied: packaging>=14.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigtable>=2.32.0->google-adk) (2.5.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigtable>=2.32.0->google-adk) (0.14.3)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigtable>=2.32.0->google-adk) (1.7.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-secret-manager<3.0.0,>=2.22.0->google-adk) (1.76.0)
# Requirement already satisfied: sqlparse>=0.4.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (2.7.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.12.0)
# Requirement already satisfied: pyjwt[crypto]>=2.10.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: alembic in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.1)
# Requirement already satisfied: tzdata in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from tzlocal<6.0,>=5.3->google-adk) (2025.2)
# Requirement already satisfied: h11>=0.8 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from uvicorn<1.0.0,>=0.34.0->google-adk) (0.16.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.76.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.28.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from shapely<3.0.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.3.4)
# Requirement already satisfied: Mako in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: pycparser in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os

load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %%
root_agent= Agent(
    name="assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
     ),
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %%
response = await runner.run_debug(
    "What is Agent Development Kit from Google? What languages is the SDK available in?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# assistant > The Agent Development Kit (ADK) from Google is a flexible and modular open-source framework designed to simplify the development, deployment, and orchestration of AI agents. It aims to make building AI agents feel more like traditional software development, allowing for greater control, easier debugging, and versioning. While optimized for Google's Gemini models and ecosystem, ADK is model-agnostic and compatible with other frameworks.
#
# The ADK is available in the following programming languages:
# *   **Python**
# *   **Java**
# *   **Go**

# %% [markdown]
# 1B
# The Problem: The "Do-It-All" Agent
#
# Single agents can do a lot. But what happens when the task gets complex? A single "monolithic" agent that tries to do research, writing, editing, and fact-checking all at once becomes a problem. Its instruction prompt gets long and confusing. It's hard to debug (which part failed?), difficult to maintain, and often produces unreliable results.
#
# The Solution: A Team of Specialists
#
# Instead of one "do-it-all" agent, we can build a multi-agent system. This is a team of simple, specialized agents that collaborate, just like a real-world team. Each agent has one clear job (e.g., one agent only does research, another only writes). This makes them easier to build, easier to test, and much more powerful and reliable when working together.
#
# To learn more, check out the documentation related to LLM agents in ADK.
#
# Architecture: Single Agent vs Multi-Agent Team

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

# %%
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

# %%
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum computing is rapidly advancing and is poised to revolutionize artificial intelligence (AI). Here's a summary of the key advancements and their implications:
#
# *   **Quantum Computing Capabilities:** Quantum computers utilize qubits, which can exist in multiple states simultaneously due to superposition. This allows them to process vast amounts of information at speeds far exceeding classical computers, addressing current limitations in AI such as immense data and power requirements for training deep learning models and solving complex optimization tasks.
# *   **Recent Advancements:** Progress includes the development of more stable qubits, improved coherence times, and advancements in quantum error correction. Companies are already demonstrating practical advantages, and breakthroughs in materials science promise exponential improvements in computational power.
# *   **Implications for AI:** The synergy between quantum computing and AI, often termed "Quantum AI," is expected to:
#     *   **Accelerate AI Training and Performance:** Leading to faster learning and more efficient data processing.
#     *   **Solve Intractable Problems:** Tackling complex challenges in areas like drug discovery, materials science, and intricate optimization problems in finance and logistics.
#     *   **Enhance Natural Language Processing (NLP):** Enabling more sophisticated AI assistants and chatbots.
#     *   **Improve Efficiency and Sustainability:** Offering a more energy-efficient solution for AI computations.
#     *   **Aid in Data Processing:** Improving data cleaning and preparation for AI training, leading to more accurate models.
#
# The quantum market is projected for substantial growth, with major breakthroughs and significant impact on science, technology, and various industries anticipated in the next decade.

# %% [markdown]
# 🚥 Section 3: Sequential Workflows - The Assembly Line¶
# The Problem: Unpredictable Order
#
# The previous multi-agent system worked, but it relied on a detailed instruction prompt to force the LLM to run steps in order. This can be unreliable. A complex LLM might decide to skip a step, run them in the wrong order, or get "stuck," making the process unpredictable.
#
# The Solution: A Fixed Pipeline
#
# When you need tasks to happen in a guaranteed, specific order, you can use a SequentialAgent. This agent acts like an assembly line, running each sub-agent in the exact order you list them. The output of one agent automatically becomes the input for the next, creating a predictable and reliable workflow.
#
# Use Sequential when: Order matters, you need a linear pipeline, or each step builds on the previous one.
#
# To learn more, check out the documentation related to sequential agents in ADK.
#
# Architecture: Blog Post Creation Pipeline

# %%
outline_agent= Agent(
     name="OutlineAgent",
     model=Gemini(
         model="gemini-2.5-flash-lite",
         retry_options=retry_config

     ),
     instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key

)

# %%
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

# %%
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Outline: The Rise of the Digital Dream Team: How Multi-Agent Systems Empower Software Developers
#
# ### Introduction Hook:
#
# Ever feel like you're juggling too many balls in the software development process? From coding to testing, deployment, and ongoing maintenance, the demands are relentless. But what if you had a team of intelligent, autonomous digital assistants working alongside you, tackling tasks and optimizing workflows? Enter Multi-Agent Systems (MAS) – a revolutionary approach that’s transforming how we build software.
#
# ### Section 1: Supercharging Productivity with Autonomous Task Management
#
# *   **Delegation Done Right:** MAS allows developers to offload repetitive or time-consuming tasks to specialized agents. Imagine agents for code review, automated refactoring, or even initial bug detection, freeing up valuable human developer time for more complex problem-solving.
# *   **Intelligent Automation:** Beyond simple task execution, agents can learn and adapt. They can identify patterns in code, anticipate potential issues, and proactively suggest solutions, leading to a significant boost in overall development velocity and quality.
# *   **24/7 Development Powerhouse:** Unlike human teams, MAS agents don't need breaks. They can continuously monitor systems, run tests, and even perform deployments outside of traditional business hours, accelerating development cycles and enabling continuous integration/continuous delivery (CI/CD) to its fullest potential.
#
# ### Section 2: Enhancing Collaboration and Knowledge Sharing
#
# *   **Bridging the Communication Gap:** Agents can act as intelligent intermediaries, facilitating communication and information exchange between different parts of a development team or even between human developers and automated systems. They can summarize logs, translate technical jargon, or highlight relevant documentation.
# *   **Decentralized Expertise:** In complex projects, knowledge can become siloed. MAS can create a distributed network of agents, each with specialized knowledge, making that expertise accessible to all developers on demand. Think of an agent that can instantly answer questions about a specific API or a legacy codebase.
# *   **Contextual Awareness:** Agents can maintain a shared understanding of the project's state, making onboarding new developers smoother and ensuring everyone is working with the latest information. They can proactively flag dependencies or potential conflicts, preventing costly mistakes.
#
# ### Section 3: Improving Software Quality and Robustness
#
# *   **Proactive Bug Detection and Prevention:** MAS agents can analyze code for common vulnerabilities, performance bottlenecks, and stylistic inconsistencies *before* they become major problems. This shifts the focus from reactive bug fixing to proactive quality assurance.
# *   **Intelligent Testing and Validation:** Agents can design and execute sophisticated test scenarios, learning from past failures to improve future test coverage. They can simulate user behavior, stress test systems, and identify edge cases that human testers might miss.
# *   **Adaptive System Maintenance:** For deployed software, MAS can monitor performance in real-time, detect anomalies, and even autonomously initiate corrective actions. This leads to more resilient and self-healing applications, reducing downtime and improving user experience.
#
# ### Section 4 (Optional - depending on desired depth): The Future is Multi-Agent: Evolving Development Paradigms
#
# *   **Beyond Individual Contribution:** MAS pushes the boundaries of individual developer contribution towards a more collaborative, AI-assisted ecosystem.
# *   **New Skillsets and Roles:** Developers may evolve into "agent orchestrators" or "MAS architects," focusing on designing, training, and managing these intelligent digital teams.
# *   **Accelerating Innovation:** By handling the mundane and the complex, MAS can unlock new possibilities for innovation, allowing developers to focus on creative problem-solving and pushing the boundaries of what’s possible.
#
# ### Concluding Thought:
#
# The era of the solo developer or the purely human team is evolving. Multi-Agent Systems aren't just a theoretical concept; they are becoming a tangible reality, offering software developers the power to build better, faster, and more robust software by embracing a new kind of digital workforce. Are you ready to build your dream team?
# WriterAgent > ## The Rise of the Digital Dream Team: How Multi-Agent Systems Empower Software Developers
#
# Ever feel like you're juggling too many balls in the software development process? From coding to testing, deployment, and ongoing maintenance, the demands are relentless. But what if you had a team of intelligent, autonomous digital assistants working alongside you, tackling tasks and optimizing workflows? Enter Multi-Agent Systems (MAS) – a revolutionary approach that’s transforming how we build software.
#
# MAS empowers developers by supercharging productivity through autonomous task management. Imagine specialized agents handling code reviews, automated refactoring, or even initial bug detection, freeing up invaluable human time for complex problem-solving. These agents learn and adapt, intelligently identifying patterns, anticipating issues, and proactively suggesting solutions. Plus, they work tirelessly, monitoring systems, running tests, and performing deployments 24/7, accelerating development cycles and enabling true CI/CD.
#
# Beyond efficiency, MAS enhances collaboration and knowledge sharing. Agents act as intelligent intermediaries, bridging communication gaps, summarizing logs, and making specialized knowledge accessible to everyone. They maintain a shared understanding of project status, smoothing onboarding and preventing costly mistakes by flagging dependencies and conflicts. This leads to significantly improved software quality and robustness. MAS agents proactively detect vulnerabilities, performance bottlenecks, and stylistic inconsistencies *before* they become major issues. They design and execute sophisticated tests, identify edge cases, and even perform adaptive system maintenance on deployed applications, leading to more resilient, self-healing software.
#
# The future of development is multi-agent. MAS is ushering in a new era of collaborative, AI-assisted ecosystems, potentially transforming developers into "agent orchestrators." By handling the mundane and the complex, MAS unlocks new avenues for innovation.
#
# The era of the purely human team is evolving. Multi-Agent Systems are becoming a tangible reality, offering developers the power to build better, faster, and more robust software. Are you ready to build your dream team?
# EditorAgent > ## The Rise of the Digital Dream Team: How Multi-Agent Systems Empower Software Developers
#
# Do you ever feel like you're juggling an overwhelming number of responsibilities in the software development process? From writing code and rigorous testing to seamless deployment and ongoing maintenance, the demands are relentless. But imagine having a team of intelligent, autonomous digital assistants working alongside you, efficiently tackling tasks and optimizing your entire workflow. This is the promise of Multi-Agent Systems (MAS) – a revolutionary approach that's transforming how we build software.
#
# MAS empowers developers by **supercharging productivity through autonomous task management**. Picture specialized agents dedicated to tasks like code reviews, automated refactoring, or even initial bug detection. This frees up invaluable human developer time, allowing you to focus on the complex problem-solving that truly drives innovation. These intelligent agents don't just execute commands; they learn and adapt. They can identify patterns in code, anticipate potential issues, and proactively suggest solutions, leading to a significant boost in development velocity and overall quality. Furthermore, MAS agents work tirelessly, monitoring systems, running tests, and performing deployments 24/7. This constant vigilance accelerates development cycles and enables true Continuous Integration and Continuous Delivery (CI/CD) to its fullest potential.
#
# Beyond sheer efficiency, MAS significantly **enhances collaboration and knowledge sharing**. Agents can act as intelligent intermediaries, bridging communication gaps, summarizing lengthy logs, and making specialized knowledge readily accessible to everyone on the team. They maintain a shared understanding of project status, smoothing the onboarding process for new members and preventing costly mistakes by proactively flagging dependencies and potential conflicts. This leads to **significantly improved software quality and robustness**. MAS agents are adept at proactively detecting vulnerabilities, performance bottlenecks, and stylistic inconsistencies *before* they escalate into major problems. They can design and execute sophisticated test scenarios, identify elusive edge cases, and even perform adaptive system maintenance on deployed applications, ultimately leading to more resilient, self-healing software.
#
# The future of software development is inherently multi-agent. MAS is ushering in a new era of collaborative, AI-assisted ecosystems, potentially transforming developers into skilled "agent orchestrators." By expertly handling both the mundane and the complex aspects of development, MAS unlocks new avenues for innovation and creativity.
#
# The era of the purely human development team is evolving. Multi-Agent Systems are rapidly transitioning from a theoretical concept to a tangible reality, offering software developers the unprecedented power to build better, faster, and more robust software. Are you ready to assemble your digital dream team?

# %% [markdown]
# Section 4: Parallel Workflows - Independent Researchers¶
# The Problem: The Bottleneck
#
# The previous sequential agent is great, but it's an assembly line. Each step must wait for the previous one to finish. What if you have several tasks that are not dependent on each other? For example, researching three different topics. Running them in sequence would be slow and inefficient, creating a bottleneck where each task waits unnecessarily.
#
# The Solution: Concurrent Execution
#
# When you have independent tasks, you can run them all at the same time using a ParallelAgent. This agent executes all of its sub-agents concurrently, dramatically speeding up the workflow. Once all parallel tasks are complete, you can then pass their combined results to a final 'aggregator' step.
#
# Use Parallel when: Tasks are independent, speed matters, and you can execute concurrently.
#
# To learn more, check out the documentation related to parallel agents in ADK.
#
# Architecture: Multi-Topic Research

# %%
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

# %%
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

# %%
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

# %%
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

# %%
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > **AI/ML Trends: Key Developments and Impact**
#
# Three key AI/ML trends shaping 2025 are:
#
# 1.  **Generative AI Expansion:** This technology is revolutionizing content creation across text, images, video, and music. Companies like OpenAI, Google, and Microsoft are leading this wave, impacting marketing, design, and software development.
# 2.  **Democratization and Accessibility of AI:** AI is becoming more accessible to smaller enterprises and non-developers through open-source solutions and low-code/no-code platforms. OpenAI exemplifies this trend, with its valuation soaring. This wider adoption is transforming industries from finance to healthcare.
# 3.  **Explainable and Ethical AI:** As AI integrates deeper into sensitive sectors like healthcare and finance, transparency in decision-making becomes crucial. This trend is driven by a need for trust and regulatory compliance, with companies focusing on developing AI systems that can explain their outputs.
#
# These trends collectively signal AI's shift from a specialized technology to a foundational element driving innovation, efficiency, and personalized experiences across various sectors.
# HealthResearcher > Here's a brief on recent breakthroughs in Tech, Health, and Finance:
#
# **Health:** mRNA vaccine technology, initially proven with COVID-19, is being explored for other diseases, with potential applications in treating HIV and cancer. Long-acting injectable antivirals like lenacapavir are revolutionizing HIV prevention and treatment, offering a more convenient alternative to daily pills. AI is increasingly integrated into healthcare for improved diagnostics and personalized treatment plans, with its market projected to reach over $600 billion by 2034.
#
# **Tech:** Agentic AI, combining AI foundation models with action-taking capabilities, is poised to create "virtual coworkers" for complex task execution. Quantum computing, while still facing development challenges, shows significant promise for drug discovery and materials science, with substantial investment pouring into startups. Brain-computer interfaces (BCIs) are advancing, with potential applications for individuals with paralysis to control devices with their thoughts.
#
# **Finance:** AI and machine learning are transforming risk decisioning and customer experience, with AI-driven financial advisors offering personalized wealth management. Blockchain technology is expanding beyond cryptocurrencies to enhance supply chain management, voting systems, and digital identity. The financial services industry is also prioritizing robust cybersecurity measures, with a focus on proactive and predictive strategies.
#
# *Estimated Timelines:* While many of these technologies are already seeing early adoption, widespread practical applications and market dominance are often projected within the next 5-10 years, with some, like AGI, having longer-term horizons.
# FinanceResearcher > Here's your executive briefing for today:
#
# **Fintech Trends:**
# 1.  **AI and ML Integration:** AI and Machine Learning are increasingly used for fraud detection, customer service, and personalization. Market implication: Enhanced efficiency, improved security, and tailored user experiences. Future outlook: Continued deep integration, leading to more sophisticated and proactive financial management tools.
# 2.  **Emerging Payment Technologies:** Mainstream adoption of new payment methods is on the rise. Market implication: Faster, more secure, and convenient transactions. Future outlook: Further innovation in payment infrastructure, potentially including wider use of stablecoins.
# 3.  **Open Banking/Finance Expansion:** Open Banking is evolving into Open Finance, extending data sharing across more financial products. Market implication: Increased competition, improved customer service, and new opportunities for innovation. Future outlook: Greater interoperability and a more holistic view of financial services for consumers.
#
# **Tech Trends:**
# 1.  **AI Everywhere & Generative AI:** AI's pervasive influence is growing, with Generative AI creating new content and capabilities. Market implication: Transformation across industries, increased automation, and new business models. Future outlook: Autonomous systems and agentic AI becoming more common, driving efficiency and problem-solving.
# 2.  **Cloud, Edge, and Connectivity:** Spending on edge computing is rising, with more critical applications moving outside centralized clouds. Market implication: Enhanced data processing capabilities closer to the source, leading to lower latency and improved performance. Future outlook: A more distributed computing infrastructure supporting real-time applications.
# 3.  **Cybersecurity Focus:** Increasing cyber threats are driving higher investment in cybersecurity solutions. Market implication: Greater emphasis on data protection, resilience, and regulatory compliance. Future outlook: AI-driven cybersecurity to combat sophisticated threats and protect sensitive data.
#
# **Health Trends:**
# 1.  **AI-Powered Diagnostics and Personalized Medicine:** AI is revolutionizing diagnostics and enabling tailored treatments. Market implication: More accurate disease prediction, improved patient outcomes, and proactive healthcare. Future outlook: AI as the backbone for diagnostics and personalized treatment plans.
# 2.  **Telehealth and Remote Patient Monitoring:** These models are shifting care delivery, improving access and managing costs. Market implication: Increased patient convenience, broader healthcare access, and better chronic disease management. Future outlook: Continued expansion of virtual care and integrated remote monitoring systems.
# 3.  **MedTech and Digital Innovation:** Advancements in medical technology and digital tools are enhancing patient engagement and operational efficiency. Market implication: Growth in wearable devices, home-based diagnostics, and digital health tools. Future outlook: Greater patient empowerment and more data-driven healthcare solutions.
# AggregatorAgent > **Executive Summary: Interconnected Innovations in Tech, Health, and Finance**
#
# Artificial Intelligence (AI) is the undeniable driving force across all three sectors, evolving from a specialized tool to a foundational element. Generative AI is revolutionizing content creation and operational efficiency, while its increasing accessibility through open-source and low-code platforms democratizes its use across industries. In finance, AI is enhancing risk assessment, customer experience, and fraud detection, with personalized wealth management on the rise.
#
# The health sector is witnessing AI's transformative power in diagnostics and personalized medicine, aiming for more accurate predictions and proactive treatment. mRNA technology, proven with COVID-19, is expanding to combat other diseases like HIV and cancer. Simultaneously, advancements in agentic AI promise "virtual coworkers," and quantum computing holds potential for breakthroughs in drug discovery.
#
# A critical common theme is the growing emphasis on explainable and ethical AI to build trust, particularly as these technologies integrate into sensitive areas like healthcare and finance. Cybersecurity remains paramount, with AI-driven solutions becoming essential to combat sophisticated threats. While many innovations are in early adoption, widespread impact is anticipated within the next 5-10 years, signaling a significant shift towards AI-powered, personalized, and more secure future across all domains.

# %% [markdown]
# Section 5: Loop Workflows - The Refinement Cycle¶
# The Problem: One-Shot Quality
#
# All the workflows we've seen so far run from start to finish. The SequentialAgent and ParallelAgent produce their final output and then stop. This 'one-shot' approach isn't good for tasks that require refinement and quality control. What if the first draft of our story is bad? We have no way to review it and ask for a rewrite.
#
# The Solution: Iterative Refinement
#
# When a task needs to be improved through cycles of feedback and revision, you can use a LoopAgent. A LoopAgent runs a set of sub-agents repeatedly until a specific condition is met or a maximum number of iterations is reached. This creates a refinement cycle, allowing the agent system to improve its own work over and over.
#
# Use Loop when: Iterative improvement is needed, quality refinement matters, or you need repeated cycles.
#
# To learn more, check out the documentation related to loop agents in ADK.
#
# Architecture: Story Writing & Critique Loop

# %%
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

# %%
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

# %%
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

# %%
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

# %%
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias traced the salt-etched lines on the worn table, the beam of his lighthouse a steady pulse against the inky sea. Tonight, the fog was a thick, suffocating blanket, muffling even the mournful cries of the gulls. He’d been polishing the brass fittings when it slipped from a loose floorboard – a map, unlike any he’d ever seen. Not parchment, but some strange, leathery material that pulsed with an inner luminescence. Intricate symbols, alien and yet strangely familiar, shimmered across its surface. As his calloused finger brushed a glowing swirl, the air crackled, and a faint, melodic hum filled the lantern room. The map wasn't showing coastlines or currents; it was showing stars, constellations he’d never charted, and a single, beckoning point of brilliant blue light.
# CriticAgent > The story has a strong atmospheric opening and introduces an intriguing mystery. However, the plot feels a bit underdeveloped, and the pacing could be improved to build suspense.
#
# Here are 2-3 specific, actionable suggestions for improvement:
#
# 1.  **Expand on the discovery and Elias's reaction:** While the discovery of the map is sudden, Elias's reaction is somewhat understated. Consider adding more detail about his internal thoughts and feelings. Is he scared, curious, or bewildered? Show his physical response to the map's magic – does his heart pound, does he feel a chill, does he hesitate before touching it? This will deepen his character and make the discovery more impactful.
# 2.  **Introduce an immediate consequence or challenge:** The map shows stars and a beckoning blue light, which is a good hook. However, to improve pacing and plot development, introduce something that happens *immediately* after Elias touches the map, or shortly thereafter. Does the lighthouse beam flicker? Does he see something unusual in the fog outside? Does a strange sound emanate from the sea? This will raise the stakes and provide a clearer direction for the narrative to follow.
# 3.  **Hint at the map's origin or purpose:** The map is "alien and yet strangely familiar." Instead of just stating this, consider weaving in a subtle clue about its origin or what it might be for. Perhaps Elias recalls an old sailor's tale, or a recurring dream, or notices a symbol on the map that vaguely resembles something he's seen before in his life on the coast. This can add depth to the mystery and provide a stronger motivation for Elias to explore further.
# RefinerAgent > Elias traced the salt-etched lines on the worn table, the beam of his lighthouse a steady pulse against the inky sea. Tonight, the fog was a thick, suffocating blanket, muffling even the mournful cries of the gulls. He’d been polishing the brass fittings when it slipped from a loose floorboard – a map, unlike any he’d ever seen. Not parchment, but some strange, leathery material that pulsed with an inner luminescence. Intricate symbols, alien and yet strangely familiar, shimmered across its surface. A shiver, unrelated to the damp chill of the lantern room, traced its way down Elias’s spine. His heart hammered against his ribs, a frantic drumbeat against the storm's low thrum. Curiosity warred with a primal fear, but his calloused finger, against his better judgment, brushed a glowing swirl. The air crackled, and a faint, melodic hum filled the lantern room, vibrating in his teeth. Suddenly, the steady beam of his lighthouse flickered, then died, plunging the lantern room into a terrifying, absolute darkness broken only by the map's eerie glow. He snatched his hand back, a gasp escaping his lips. The map wasn't showing coastlines or currents; it was showing stars, constellations he’d never charted, and a single, beckoning point of brilliant blue light. As he stared, a symbol near the blue light pulsed, and Elias felt an echo of a forgotten lullaby his grandmother used to sing, a song about the sea and the stars. Could this map be connected to the old tales of the 'star-fallen' treasure? The thought sent another jolt through him, a mix of dread and a powerful, undeniable pull.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
